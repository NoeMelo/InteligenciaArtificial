# %% [markdown]
# ## Obtener Imágenes

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://es.wikipedia.org/wiki/Pablo_Picasso'

# %%
# Obtener el contenido
content = requests.get(url).content

# %%
content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Pablo Picasso - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Pablo_Picasso","wgTitle":"Pablo Picasso","wgCurRevisionId":116447309,"wgRevisionId":116447309,"wgArticleId":2147,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:P\xc3\xa1ginas con enlaces m\xc3\xa1gicos de ISBN","Wikipedia:Art\xc3\xadculos destacados en la Wikipedia en siciliano","Wikipedia:Art\xc3\xadculos buenos en la Wikipedia en fin\xc3\xa9s","Wikipedia:Art\xc3\xadculos destacados en la Wikipedia en ucraniano","Wikipedia:Art\xc3\xadculos destacados en la Wikipedia en alem\xc3\xa1n","Wikipedia:Art\xc3\xadculos con identi
# ...

# %%
# Obtener soup
soup = BeautifulSoup(content,'lxml') # choose lxml parser

# %%
# Encontrar los tag : <img ... >
image_tags = soup.findAll('img')

# %%
image_tags
# Out:
# [<img alt="Pablo picasso 1.jpg" data-file-height="1270" data-file-width="1080" decoding="async" elementtiming="thumbnail-top" height="235" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/200px-Pablo_picasso_1.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/300px-Pablo_picasso_1.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/400px-Pablo_picasso_1.jpg 2x" width="200"/>,
#  <img alt="Ver y modificar los datos en Wikidata" data-file-height="600" data-file-width="600" decoding="async" elementtiming="thumbnail" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/15px-Blue_pencil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/20px-Blue_pencil.svg.png 2x" style="vertical-align: baseline" width="10"/>,
# ...

# %%
image_tags[0]
# Out:
# <img alt="Pablo picasso 1.jpg" data-file-height="1270" data-file-width="1080" decoding="async" elementtiming="thumbnail-top" height="235" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/200px-Pablo_picasso_1.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/300px-Pablo_picasso_1.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/400px-Pablo_picasso_1.jpg 2x" width="200"/>

# %%
image_tags[0].get('src')
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/200px-Pablo_picasso_1.jpg'

# %%
# Imprimir las imágenes
for image_tag in image_tags:
    print(image_tag.get('src'))
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Pablo_picasso_1.jpg/200px-Pablo_picasso_1.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/7/73/Blue_pencil.svg/10px-Blue_pencil.svg.png
# ...

# %%
#!pip install wget

# %%
import wget

# %%
wget.download("https:"+image_tags[0].get('src'))
# Out:
# 100% [..............................................................................] 17154 / 17154
# '200px-Pablo_picasso_1.jpg'

# %%
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 22C3-90EE
#
#  Directorio de C:\Users\laboratorioesan\Desktop\BS-20190605
#
# 05/06/2019  09:03    <DIR>          .
# 05/06/2019  09:03    <DIR>          ..
# 05/06/2019  08:46    <DIR>          .ipynb_checkpoints
# 05/06/2019  09:03            17,154 200px-Pablo_picasso_1.jpg
# 05/06/2019  09:00         1,122,991 BS1.ipynb
# 05/06/2019  09:02           890,610 BS2.ipynb
# 05/06/2019  08:45             5,498 BS3.ipynb
# 05/06/2019  08:46            61,262 BS4.ipynb
#                5 archivos      2,097,515 bytes
#                3 dirs  58,327,666,688 bytes libres

# %%
lista1 = soup.find_all('p')#parrafos, all devuelve todo los elementos

# %%
len(lista1)
# Out:
# 142

# %%
print(lista1[0].text)
# Out:
# Pablo Ruiz Picasso (Málaga, 25 de octubre de 1881-Mougins, 8 de abril de 1973) fue un pintor y escultor español, creador, junto con Georges Braque, del cubismo.

# %%
for lista in lista1:
    print(lista.text)
# Out:
# Pablo Ruiz Picasso (Málaga, 25 de octubre de 1881-Mougins, 8 de abril de 1973) fue un pintor y escultor español, creador, junto con Georges Braque, del cubismo.
#
# Es considerado desde la génesis del siglo XX como uno de los mayores pintores que participaron en muchos movimientos artísticos que se propagaron por el mundo y ejercieron una gran influencia en otros grandes artistas de su tiempo. Sus trabajos están presentes en museos y colecciones de toda Europa y del mundo. Además, abordó otros géneros como el dibujo, el grabado, la ilustración de libros, la escultura, la cerámica y el diseño de escenografía y vestuario para montajes teatrales. También tiene una breve obra literaria.
#
# ...
