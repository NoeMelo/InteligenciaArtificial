# %% [markdown]
# # <CENTER>BEAUTIFUL SOUP (BS4)</CENTER>

# %% [markdown]
# Web Oficial
# <br>
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ## Obtener Índice

# %%
from bs4 import BeautifulSoup
import requests#conexion con la pagina web:   crawler python

# %%
#URL inicial
#
url = 'https://es.wikipedia.org/wiki/Sevilla'

# %%
# Obtener Links
content = requests.get(url).content

# %%
content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Sevilla - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Sevilla","wgTitle":"Sevilla","wgCurRevisionId":116457244,"wgRevisionId":116457244,"wgArticleId":8079,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:P\xc3\xa1ginas que utilizan Timeline","Wikipedia:P\xc3\xa1ginas con errores de referencia","Wikipedia:P\xc3\xa1ginas con plantillas con argumentos duplicados","Wikipedia:P\xc3\xa1ginas con referencias con par\xc3\xa1metros obsoletos","Wikipedia:P\xc3\xa1ginas con referencias sin fechaarchivo y con urlarchivo","Wikipedia:P\xc3\xa1ginas con enlaces m\xc3\xa1gicos de ISBN","Wikipedia:Ar
# ...

# %%
# Obtener soup
soup = BeautifulSoup(content,'lxml') # choose lxml parser, ESTRUCTURA LA PÁGINA EN FORMA DE ARBOL: HEAD -> link, title ,BODY:h1,h2,p,i,etc

# %%
# Ubicar tags : <div class="toc">
tag = soup.find('div', {'class' : 'toc'}) # id="toc" also works

# %%
tag
# Out:
# <div class="toc" id="toc"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="es"><h2>Índice</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Elementos_identitarios"><span class="tocnumber">1</span> <span class="toctext">Elementos identitarios</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Toponimia"><span class="tocnumber">1.1</span> <span class="toctext">Toponimia</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Símbolos_de_Sevilla"><span class="tocnumber">1.2</span> <span class="toctext">Símbolos de Sevilla</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-4"><a href="#Geografía"><span class="tocnumber">2</span> <span class="toctext">Geografía</span></a>
# <ul>
# ...

# %%
# Obtener los links "<a>"
links = tag.findAll('a') # <a href='/path/to/div'>topic</a>

# %%
links[2]
# Out:
# <a href="#Símbolos_de_Sevilla"><span class="tocnumber">1.2</span> <span class="toctext">Símbolos de Sevilla</span></a>

# %%
len(links)
# Out:
# 90

# %%
links[0]
# Out:
# <a href="#Elementos_identitarios"><span class="tocnumber">1</span> <span class="toctext">Elementos identitarios</span></a>

# %%
links[0].text
# Out:
# '1 Elementos identitarios'

# %%
# Imprimir textos
for link in links:
  print(link.text) # Obtener los textos <a>
# Out:
# 1 Elementos identitarios
# 1.1 Toponimia
# 1.2 Símbolos de Sevilla
# 2 Geografía
# 2.1 Ubicación
# 2.2 Relieve
# 2.3 Hidrografía
# 2.4 Clima
# 2.5 Flora y fauna
# 2.6 Contaminación atmosférica y acústica
# 3 Historia
# 3.1 Sevilla en la Antigüedad
# 3.2 Sevilla en la Edad Media
# 3.3 Sevilla en la Edad Moderna
# 3.4 Sevilla contemporánea
# 4 Demografía
# 5 Administración y política
# 5.1 Capitalidad
# 5.2 Área metropolitana de Sevilla
# 5.3 Organización municipal
# 5.4 Lista de alcaldes desde las elecciones democráticas de 1979
# 5.5 Áreas de servicio municipales
# 5.6 Administración judicial
# 6 Patrimonio
# 6.1 Monumentos
# 6.1.1 Catedral
# 6.1.2 Giralda
# 6.1.3 Real Alcázar
# 6.1.4 Archivo de Indias
# 6.1.5 Plaza de España
# 6.1.6 Torre del Oro
# 6.1.7 Setas de Sevilla
# 6.1.8 Otros monumentos
# 6.1.9 Barrio de Santa Cruz
# 6.2 Urbanismo
# 6.3 Parques y jardines
# 7 Economía
# 7.1 Empleo
# 7.2 Estructura productiva
# 7.2.1 Agricultura
# 7.2.2 Industria
# 7.2.3 Construcción
# ...
