# %%
from gensim.models import word2vec
import numpy as np
import gensim
from multiprocessing import cpu_count
#model = Word2Vec(sentences, min_count = 0, workers=cpu_count())
# Out:
# Using TensorFlow backend.

# %%
cpu_count()
# Out:
# 4

# %%
sentences = word2vec.Text8Corpus('text8')

# %%
sentences

# %%
model = word2vec.Word2Vec(sentences, size=100,min_count=2)

# %%
model.wv.vocab
# Out:
# {'anarchism': <gensim.models.keyedvectors.Vocab at 0x12094b048>,
#  'originated': <gensim.models.keyedvectors.Vocab at 0x12094b080>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x12094b0b8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x12094b0f0>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x12094b128>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x12094b160>,
#  'abuse': <gensim.models.keyedvectors.Vocab at 0x12094b198>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x12094b1d0>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x12094b208>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x12094b240>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x12094b278>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x12094b2b0>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x12094b2e8>,
#  'radicals': <gensim.models.keyedvectors.Vocab at 0x12094b320>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x12094b358>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x12094b390>,
#  'diggers': <gensim.models.keyedvectors.Vocab at 0x12094b3c8>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x12094b400>,
#  'revolution': <gensim.models.keyedvectors.Vocab at 0x12094b438>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x12094b470>,
#  'sans': <gensim.models.keyedvectors.Vocab at 0x12094b4a8>,
#  'culottes': <gensim.models.keyedvectors.Vocab at 0x12094b4e0>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x12094b518>,
#  'whilst': <gensim.models.keyedvectors.Vocab at 0x12094b550>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x12094b5c0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x12094b5f8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x12094b668>,
#  'pejorative': <gensim.models.keyedvectors.Vocab at 0x12094b6a0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x12094b6d8>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x12094b710>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x12094b748>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x12094b7b8>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x12094b7f0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x12094b828>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x12094b860>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x12094b8d0>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x12094b908>,
#  'organization': <gensim.models.keyedvectors.Vocab at 0x12094b978>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x12094b9b0>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x12094b9e8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x12094ba20>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x12094ba58>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x12094ba90>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x12094bb00>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x12094bb38>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x12094bb70>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x12094bba8>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x12094bc18>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x12094bc50>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x12094bcc0>,
#  'anarchists': <gensim.models.keyedvectors.Vocab at 0x12094bcf8>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x12094bd30>,
#  'derived': <gensim.models.keyedvectors.Vocab at 0x12094bd68>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x12094bda0>,
#  'greek': <gensim.models.keyedvectors.Vocab at 0x12094be80>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x12094beb8>,
#  'archons': <gensim.models.keyedvectors.Vocab at 0x12094bf60>,
#  'ruler': <gensim.models.keyedvectors.Vocab at 0x12094bf98>,
#  'chief': <gensim.models.keyedvectors.Vocab at 0x1208585f8>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x120858080>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x1208580b8>,
#  'philosophy': <gensim.models.keyedvectors.Vocab at 0x1208580f0>,
#  'belief': <gensim.models.keyedvectors.Vocab at 0x120858128>,
#  'rulers': <gensim.models.keyedvectors.Vocab at 0x120858160>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1208582b0>,
#  'unnecessary': <gensim.models.keyedvectors.Vocab at 0x120858390>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x1208583c8>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x120858438>,
#  'abolished': <gensim.models.keyedvectors.Vocab at 0x120858470>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x1208584e0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x120858550>,
#  'differing': <gensim.models.keyedvectors.Vocab at 0x120858588>,
#  'interpretations': <gensim.models.keyedvectors.Vocab at 0x1208585c0>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x120858630>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x120858668>,
#  'refers': <gensim.models.keyedvectors.Vocab at 0x1208586a0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x120858748>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x1208587f0>,
#  'movements': <gensim.models.keyedvectors.Vocab at 0x120858828>,
#  'advocate': <gensim.models.keyedvectors.Vocab at 0x120858898>,
#  'elimination': <gensim.models.keyedvectors.Vocab at 0x120858908>,
#  'authoritarian': <gensim.models.keyedvectors.Vocab at 0x120858940>,
#  'institutions': <gensim.models.keyedvectors.Vocab at 0x120858a20>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x120858ac8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x120858b00>,
#  'anarchy': <gensim.models.keyedvectors.Vocab at 0x120858b38>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x120858b70>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x120858c88>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x120858cc0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x120858cf8>,
#  'imply': <gensim.models.keyedvectors.Vocab at 0x120858d30>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x120858d68>,
#  'nihilism': <gensim.models.keyedvectors.Vocab at 0x120858da0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x120858dd8>,
#  'anomie': <gensim.models.keyedvectors.Vocab at 0x120858e80>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x120858eb8>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x120858f28>,
#  'harmonious': <gensim.models.keyedvectors.Vocab at 0x120858fd0>,
#  'anti': <gensim.models.keyedvectors.Vocab at 0x11fad65f8>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x11fad6a58>,
#  'regarded': <gensim.models.keyedvectors.Vocab at 0x11fad6f28>,
#  'structures': <gensim.models.keyedvectors.Vocab at 0x11fad6f60>,
#  'coercive': <gensim.models.keyedvectors.Vocab at 0x11fad64e0>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x11fad6240>,
#  'relations': <gensim.models.keyedvectors.Vocab at 0x11fad6278>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x11fad62b0>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x11fad62e8>,
#  'voluntary': <gensim.models.keyedvectors.Vocab at 0x11fad6470>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x11f9b0c88>,
#  'autonomous': <gensim.models.keyedvectors.Vocab at 0x11f9b0fd0>,
#  'individuals': <gensim.models.keyedvectors.Vocab at 0x11f663240>,
#  'mutual': <gensim.models.keyedvectors.Vocab at 0x11ef23208>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x11f011828>,
#  'governance': <gensim.models.keyedvectors.Vocab at 0x11efa5a90>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x11f748be0>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x11f7482b0>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x11ef4c048>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x11ee460b8>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x11ead3898>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x11faea128>,
#  'truly': <gensim.models.keyedvectors.Vocab at 0x11faea898>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x11faeae10>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x11f6916a0>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x11f84ab38>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x11f84af28>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x11f77a4a8>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x11f77c588>,
#  'anarchist': <gensim.models.keyedvectors.Vocab at 0x11f7c8630>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x11f6d6828>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x12061e390>,
#  'vary': <gensim.models.keyedvectors.Vocab at 0x12061e1d0>,
#  'considerably': <gensim.models.keyedvectors.Vocab at 0x12061e2b0>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x12061e320>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x12061e358>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x12061e470>,
#  'economics': <gensim.models.keyedvectors.Vocab at 0x12061e780>,
#  'disagreement': <gensim.models.keyedvectors.Vocab at 0x12061e908>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x12061e978>,
#  'origins': <gensim.models.keyedvectors.Vocab at 0x12061eac8>,
#  'predecessors': <gensim.models.keyedvectors.Vocab at 0x120899080>,
#  'kropotkin': <gensim.models.keyedvectors.Vocab at 0x1208990b8>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x120899278>,
#  'argue': <gensim.models.keyedvectors.Vocab at 0x1208992e8>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x120899320>,
#  'recorded': <gensim.models.keyedvectors.Vocab at 0x120899358>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x1208993c8>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x120899400>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x120899470>,
#  'organized': <gensim.models.keyedvectors.Vocab at 0x1208994a8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1208994e0>,
#  'principles': <gensim.models.keyedvectors.Vocab at 0x120899518>,
#  'anthropologists': <gensim.models.keyedvectors.Vocab at 0x120899550>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x1208995c0>,
#  'engels': <gensim.models.keyedvectors.Vocab at 0x1208996a0>,
#  'believing': <gensim.models.keyedvectors.Vocab at 0x120899710>,
#  'hunter': <gensim.models.keyedvectors.Vocab at 0x120899748>,
#  'gatherer': <gensim.models.keyedvectors.Vocab at 0x1208997b8>,
#  'bands': <gensim.models.keyedvectors.Vocab at 0x1208997f0>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x120899860>,
#  'egalitarian': <gensim.models.keyedvectors.Vocab at 0x120899898>,
#  'lacked': <gensim.models.keyedvectors.Vocab at 0x1208998d0>,
#  'division': <gensim.models.keyedvectors.Vocab at 0x120899908>,
#  'labour': <gensim.models.keyedvectors.Vocab at 0x1208999e8>,
#  'accumulated': <gensim.models.keyedvectors.Vocab at 0x120899a20>,
#  'wealth': <gensim.models.keyedvectors.Vocab at 0x120899a90>,
#  'decreed': <gensim.models.keyedvectors.Vocab at 0x120899b70>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x120899ba8>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x120899be0>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x120899c50>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x120899cc0>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x120899cf8>,
#  'william': <gensim.models.keyedvectors.Vocab at 0x120899d30>,
#  'godwin': <gensim.models.keyedvectors.Vocab at 0x120899d68>,
#  'organisation': <gensim.models.keyedvectors.Vocab at 0x120899da0>,
#  'rothbard': <gensim.models.keyedvectors.Vocab at 0x120899dd8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x120899eb8>,
#  'attitudes': <gensim.models.keyedvectors.Vocab at 0x120899ef0>,
#  'taoism': <gensim.models.keyedvectors.Vocab at 0x120899f28>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x120899f60>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x120899f98>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x120899fd0>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x1207b6940>,
#  'stoic': <gensim.models.keyedvectors.Vocab at 0x1207b6978>,
#  'zeno': <gensim.models.keyedvectors.Vocab at 0x1207b69b0>,
#  'citium': <gensim.models.keyedvectors.Vocab at 0x1207b69e8>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x1207b6a90>,
#  'repudiated': <gensim.models.keyedvectors.Vocab at 0x1207b6b38>,
#  'omnipotence': <gensim.models.keyedvectors.Vocab at 0x1207b6c18>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1207b6c50>,
#  'intervention': <gensim.models.keyedvectors.Vocab at 0x1207b6cc0>,
#  'regimentation': <gensim.models.keyedvectors.Vocab at 0x1207b6d30>,
#  'proclaimed': <gensim.models.keyedvectors.Vocab at 0x1207b6dd8>,
#  'sovereignty': <gensim.models.keyedvectors.Vocab at 0x1207b6e10>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x1207b6e48>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x1207b6eb8>,
#  'anabaptists': <gensim.models.keyedvectors.Vocab at 0x1207b6ef0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1207b6f28>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x1207b6fd0>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x1207b68d0>,
#  'century': <gensim.models.keyedvectors.Vocab at 0x1207b6048>,
#  'europe': <gensim.models.keyedvectors.Vocab at 0x1207b60f0>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x1207b6208>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x1207b62b0>,
#  'religious': <gensim.models.keyedvectors.Vocab at 0x1207b62e8>,
#  'forerunners': <gensim.models.keyedvectors.Vocab at 0x1207b6320>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1207b6390>,
#  'bertrand': <gensim.models.keyedvectors.Vocab at 0x1207b6470>,
#  'russell': <gensim.models.keyedvectors.Vocab at 0x1207b64e0>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1207b65c0>,
#  'western': <gensim.models.keyedvectors.Vocab at 0x1207b6630>,
#  'writes': <gensim.models.keyedvectors.Vocab at 0x1207b6668>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1207b6780>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1207b67b8>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x1207b67f0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1207b6860>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1208ea048>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1208ea080>,
#  'guided': <gensim.models.keyedvectors.Vocab at 0x1208ea0f0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1208ea128>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1208ea160>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x1208ea198>,
#  'holy': <gensim.models.keyedvectors.Vocab at 0x1208ea1d0>,
#  'spirit': <gensim.models.keyedvectors.Vocab at 0x1208ea240>,
#  'premise': <gensim.models.keyedvectors.Vocab at 0x1208ea278>,
#  'arrive': <gensim.models.keyedvectors.Vocab at 0x1208ea2b0>,
#  'communism': <gensim.models.keyedvectors.Vocab at 0x1208ea358>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1208ea390>,
#  'levellers': <gensim.models.keyedvectors.Vocab at 0x1208ea3c8>,
#  'communistic': <gensim.models.keyedvectors.Vocab at 0x1208ea400>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x1208ea438>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x1208ea470>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1208ea4a8>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x1208ea4e0>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x1208ea550>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1208ea588>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x1208ea5c0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1208ea630>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x1208ea668>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x1208ea6a0>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x1208ea6d8>,
#  'louis': <gensim.models.keyedvectors.Vocab at 0x1208ea710>,
#  'armand': <gensim.models.keyedvectors.Vocab at 0x1208ea780>,
#  'baron': <gensim.models.keyedvectors.Vocab at 0x1208ea828>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x1208ea860>,
#  'lahontan': <gensim.models.keyedvectors.Vocab at 0x1208ea898>,
#  'nouveaux': <gensim.models.keyedvectors.Vocab at 0x1208ea8d0>,
#  'voyages': <gensim.models.keyedvectors.Vocab at 0x1208ea908>,
#  'dans': <gensim.models.keyedvectors.Vocab at 0x1208ea978>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x1208ea9b0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x1208ea9e8>,
#  'rique': <gensim.models.keyedvectors.Vocab at 0x1208eaa20>,
#  'septentrionale': <gensim.models.keyedvectors.Vocab at 0x1208eaa58>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x1208eaac8>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x1208eab38>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1208eab70>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x1208eabe0>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x1208eac88>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x1208ead30>,
#  'indigenous': <gensim.models.keyedvectors.Vocab at 0x1208eadd8>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x1208eae10>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x1208eaeb8>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x1208eaef0>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x1208eaf28>,
#  'prisons': <gensim.models.keyedvectors.Vocab at 0x1208eaf60>,
#  'priests': <gensim.models.keyedvectors.Vocab at 0x1208eafd0>,
#  'private': <gensim.models.keyedvectors.Vocab at 0x1208eb048>,
#  'property': <gensim.models.keyedvectors.Vocab at 0x1208eb0b8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x1208eb0f0>,
#  'libertarian': <gensim.models.keyedvectors.Vocab at 0x1208eb160>,
#  'leader': <gensim.models.keyedvectors.Vocab at 0x1208eb1d0>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x1208eb208>,
#  'repeatedly': <gensim.models.keyedvectors.Vocab at 0x1208eb240>,
#  'stated': <gensim.models.keyedvectors.Vocab at 0x1208eb278>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1208eb2b0>,
#  'ancestors': <gensim.models.keyedvectors.Vocab at 0x1208eb2e8>,
#  'nine': <gensim.models.keyedvectors.Vocab at 0x1208eb358>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x1208eb400>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x1208eb438>,
#  'enquiry': <gensim.models.keyedvectors.Vocab at 0x1208eb4a8>,
#  'concerning': <gensim.models.keyedvectors.Vocab at 0x1208eb4e0>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x1208eb550>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x1208eb5c0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x1208eb630>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x1208eb6a0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x1208eb780>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x1208eb828>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1208eb898>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x1208eb8d0>,
#  'founder': <gensim.models.keyedvectors.Vocab at 0x1208eb908>,
#  'philosophical': <gensim.models.keyedvectors.Vocab at 0x1208eb978>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1208eb9b0>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1208eba20>,
#  'existed': <gensim.models.keyedvectors.Vocab at 0x1208eba58>,
#  'anarchiste': <gensim.models.keyedvectors.Vocab at 0x1208eba90>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1208ebac8>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x1208ebb38>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x1208ebba8>,
#  'hurled': <gensim.models.keyedvectors.Vocab at 0x1208ebcc0>,
#  'bourgeois': <gensim.models.keyedvectors.Vocab at 0x1208ebcf8>,
#  'girondins': <gensim.models.keyedvectors.Vocab at 0x1208ebda0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1208ebdd8>,
#  'radical': <gensim.models.keyedvectors.Vocab at 0x1208ebe80>,
#  'elements': <gensim.models.keyedvectors.Vocab at 0x1208ebef0>,
#  'labelled': <gensim.models.keyedvectors.Vocab at 0x1208ebf28>,
#  'pierre': <gensim.models.keyedvectors.Vocab at 0x1208ebfd0>,
#  'joseph': <gensim.models.keyedvectors.Vocab at 0x1208ec4e0>,
#  'proudhon': <gensim.models.keyedvectors.Vocab at 0x1208ec518>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x1208ec550>,
#  'wasn': <gensim.models.keyedvectors.Vocab at 0x1208ec588>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1208ec5c0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x1208ec5f8>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x1208ec668>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x1208ec7f0>,
#  'adopted': <gensim.models.keyedvectors.Vocab at 0x1208ec860>,
#  'description': <gensim.models.keyedvectors.Vocab at 0x1208ec898>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1208ec8d0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x1208ec908>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x1208ec940>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x1208ec9b0>,
#  'answers': <gensim.models.keyedvectors.Vocab at 0x1208ec9e8>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x1208eca20>,
#  'accusation': <gensim.models.keyedvectors.Vocab at 0x1208eca58>,
#  'theft': <gensim.models.keyedvectors.Vocab at 0x1208eca90>,
#  'opposed': <gensim.models.keyedvectors.Vocab at 0x1208ecb00>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x1208ecba8>,
#  'propri': <gensim.models.keyedvectors.Vocab at 0x1208ecc50>,
#  'owners': <gensim.models.keyedvectors.Vocab at 0x1208ecc88>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x1208eccc0>,
#  'rights': <gensim.models.keyedvectors.Vocab at 0x1208ecd30>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x1208ecda0>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x1208ecdd8>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x1208ece10>,
#  'exploiting': <gensim.models.keyedvectors.Vocab at 0x1208ece48>,
#  'workers': <gensim.models.keyedvectors.Vocab at 0x1208ece80>,
#  'profit': <gensim.models.keyedvectors.Vocab at 0x1208eceb8>,
#  'supported': <gensim.models.keyedvectors.Vocab at 0x1208ecef0>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1208ecf28>,
#  'possession': <gensim.models.keyedvectors.Vocab at 0x1208ecf60>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x1208ecfd0>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x1208ec048>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x1208ec080>,
#  'goods': <gensim.models.keyedvectors.Vocab at 0x1208ec0b8>,
#  'accordance': <gensim.models.keyedvectors.Vocab at 0x1208ec0f0>,
#  'equality': <gensim.models.keyedvectors.Vocab at 0x1208ec128>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1208ec160>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x1208ec198>,
#  'mutualism': <gensim.models.keyedvectors.Vocab at 0x1208ec1d0>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x1208ec208>,
#  'exchange': <gensim.models.keyedvectors.Vocab at 0x1208ec240>,
#  'economy': <gensim.models.keyedvectors.Vocab at 0x1208ec278>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x1208ec2b0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1208ec2e8>,
#  'trade': <gensim.models.keyedvectors.Vocab at 0x1208ec320>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x1208ec358>,
#  'labor': <gensim.models.keyedvectors.Vocab at 0x1208ec390>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x1206b9588>,
#  'notes': <gensim.models.keyedvectors.Vocab at 0x1206b9748>,
#  'represented': <gensim.models.keyedvectors.Vocab at 0x1206b9898>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x1206b9908>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x1206b9978>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1206b99b0>,
#  'ensure': <gensim.models.keyedvectors.Vocab at 0x1206b9a20>,
#  'freely': <gensim.models.keyedvectors.Vocab at 0x1206b9a90>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x1206b9ba8>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1206b9dd8>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x1206b9e10>,
#  'operative': <gensim.models.keyedvectors.Vocab at 0x1206b94a8>,
#  'workshops': <gensim.models.keyedvectors.Vocab at 0x1206b9e48>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x1206b9eb8>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x1206b9f60>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1206b90b8>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x1205836d8>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x120583710>,
#  'influential': <gensim.models.keyedvectors.Vocab at 0x1205837f0>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x120583860>,
#  'followers': <gensim.models.keyedvectors.Vocab at 0x1205839b0>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x120583c88>,
#  'france': <gensim.models.keyedvectors.Vocab at 0x120583cf8>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x120583e48>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x120583f60>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x120583fd0>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x120583358>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x120583a58>,
#  'lifetime': <gensim.models.keyedvectors.Vocab at 0x1205831d0>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x1205832e8>,
#  'discussion': <gensim.models.keyedvectors.Vocab at 0x1205cf128>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1205cf198>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x1205cf518>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x1205cf668>,
#  'stirner': <gensim.models.keyedvectors.Vocab at 0x1205cf748>,
#  'egoism': <gensim.models.keyedvectors.Vocab at 0x1205cf7b8>,
#  'ego': <gensim.models.keyedvectors.Vocab at 0x1205cf828>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x1205cf8d0>,
#  'argued': <gensim.models.keyedvectors.Vocab at 0x1205cf9b0>,
#  'accepted': <gensim.models.keyedvectors.Vocab at 0x1205cfb00>,
#  'notion': <gensim.models.keyedvectors.Vocab at 0x1205cfb70>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1205cfc50>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x1205cfd30>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x1205cfdd8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1205cfe80>,
#  'mere': <gensim.models.keyedvectors.Vocab at 0x1205cff60>,
#  'illusions': <gensim.models.keyedvectors.Vocab at 0x12080c7f0>,
#  'ghosts': <gensim.models.keyedvectors.Vocab at 0x12080c860>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x12080c898>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x12080c8d0>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x12080c9b0>,
#  'advocated': <gensim.models.keyedvectors.Vocab at 0x12080ca58>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x12080ca90>,
#  'amoralism': <gensim.models.keyedvectors.Vocab at 0x12080cb70>,
#  'unite': <gensim.models.keyedvectors.Vocab at 0x12080ccf8>,
#  'associations': <gensim.models.keyedvectors.Vocab at 0x12080ce48>,
#  'egoists': <gensim.models.keyedvectors.Vocab at 0x12080ceb8>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x12080cef0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x12080cf60>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x12080cf98>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x12080cfd0>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x12080c208>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x12080c2e8>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x12080c320>,
#  'whoever': <gensim.models.keyedvectors.Vocab at 0x12080c358>,
#  'knows': <gensim.models.keyedvectors.Vocab at 0x12080c3c8>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x12080c5f8>,
#  'defend': <gensim.models.keyedvectors.Vocab at 0x120684940>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x120684a58>,
#  'belongs': <gensim.models.keyedvectors.Vocab at 0x120684da0>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x120684e48>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x120684fd0>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x120684320>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1206842e8>,
#  'assert': <gensim.models.keyedvectors.Vocab at 0x120684048>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x120684160>,
#  'holder': <gensim.models.keyedvectors.Vocab at 0x120684240>,
#  'proprietor': <gensim.models.keyedvectors.Vocab at 0x120684470>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1206844a8>,
#  'himself': <gensim.models.keyedvectors.Vocab at 0x1206844e0>,
#  'egoist': <gensim.models.keyedvectors.Vocab at 0x120684518>,
#  'nevertheless': <gensim.models.keyedvectors.Vocab at 0x120684630>,
#  'inclined': <gensim.models.keyedvectors.Vocab at 0x120684668>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1206846a0>,
#  'diverse': <gensim.models.keyedvectors.Vocab at 0x1206846d8>,
#  'individualist': <gensim.models.keyedvectors.Vocab at 0x11fa405c0>,
#  'benjamin': <gensim.models.keyedvectors.Vocab at 0x11fa40780>,
#  'tucker': <gensim.models.keyedvectors.Vocab at 0x11fa40a58>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x11fa40e48>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x11fa40e80>,
#  'josiah': <gensim.models.keyedvectors.Vocab at 0x11fa40160>,
#  'warren': <gensim.models.keyedvectors.Vocab at 0x11fa40470>,
#  'participated': <gensim.models.keyedvectors.Vocab at 0x120596080>,
#  'communitarian': <gensim.models.keyedvectors.Vocab at 0x120596160>,
#  'experiment': <gensim.models.keyedvectors.Vocab at 0x1205961d0>,
#  'headed': <gensim.models.keyedvectors.Vocab at 0x1205962b0>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x1205963c8>,
#  'owen': <gensim.models.keyedvectors.Vocab at 0x120596400>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1205964a8>,
#  'harmony': <gensim.models.keyedvectors.Vocab at 0x120596518>,
#  'failed': <gensim.models.keyedvectors.Vocab at 0x1205966a0>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x120596860>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x120596898>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x1205968d0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x120596b00>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x120596be0>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x120596c50>,
#  'blamed': <gensim.models.keyedvectors.Vocab at 0x120596da0>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x120596f28>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x120856048>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x120856080>,
#  'proceeded': <gensim.models.keyedvectors.Vocab at 0x120856cf8>,
#  'organise': <gensim.models.keyedvectors.Vocab at 0x120856d30>,
#  'communities': <gensim.models.keyedvectors.Vocab at 0x120856d68>,
#  'respected': <gensim.models.keyedvectors.Vocab at 0x120856da0>,
#  'utopia': <gensim.models.keyedvectors.Vocab at 0x120856dd8>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x120856e10>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x120856e48>,
#  'peaceful': <gensim.models.keyedvectors.Vocab at 0x120856eb8>,
#  'revolutionist': <gensim.models.keyedvectors.Vocab at 0x120856ef0>,
#  'noted': <gensim.models.keyedvectors.Vocab at 0x120856f28>,
#  'periodical': <gensim.models.keyedvectors.Vocab at 0x120856f60>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x120856fd0>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x1208560f0>,
#  'expound': <gensim.models.keyedvectors.Vocab at 0x120856128>,
#  'formulate': <gensim.models.keyedvectors.Vocab at 0x120856160>,
#  'doctrine': <gensim.models.keyedvectors.Vocab at 0x120856198>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x1208561d0>,
#  'liberty': <gensim.models.keyedvectors.Vocab at 0x120856208>,
#  'xiv': <gensim.models.keyedvectors.Vocab at 0x1208562e8>,
#  'december': <gensim.models.keyedvectors.Vocab at 0x120856358>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x120856400>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x120856470>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x120856518>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x120856550>,
#  'greene': <gensim.models.keyedvectors.Vocab at 0x1208565c0>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x1208565f8>,
#  'august': <gensim.models.keyedvectors.Vocab at 0x120856630>,
#  'april': <gensim.models.keyedvectors.Vocab at 0x120856668>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x1208566a0>,
#  'finest': <gensim.models.keyedvectors.Vocab at 0x1208566d8>,
#  'issued': <gensim.models.keyedvectors.Vocab at 0x120856710>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x120856748>,
#  'conception': <gensim.models.keyedvectors.Vocab at 0x1208567b8>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x120856828>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x120856860>,
#  'theorists': <gensim.models.keyedvectors.Vocab at 0x120856898>,
#  'banking': <gensim.models.keyedvectors.Vocab at 0x1208568d0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x120856908>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x120856940>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x120856978>,
#  'heterodox': <gensim.models.keyedvectors.Vocab at 0x1208569b0>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x120856a20>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x120856a58>,
#  'herbert': <gensim.models.keyedvectors.Vocab at 0x120856a90>,
#  'spencer': <gensim.models.keyedvectors.Vocab at 0x120856ac8>,
#  'freedom': <gensim.models.keyedvectors.Vocab at 0x120856b00>,
#  'strongly': <gensim.models.keyedvectors.Vocab at 0x120856b38>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x120856b70>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x120856be0>,
#  'believed': <gensim.models.keyedvectors.Vocab at 0x120856c18>,
#  'trading': <gensim.models.keyedvectors.Vocab at 0x1207bdd68>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1207bd048>,
#  'abundance': <gensim.models.keyedvectors.Vocab at 0x1207bd0b8>,
#  'competition': <gensim.models.keyedvectors.Vocab at 0x1207bd0f0>,
#  'eliminate': <gensim.models.keyedvectors.Vocab at 0x1207bd198>,
#  'profits': <gensim.models.keyedvectors.Vocab at 0x1207bd208>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x1207bd278>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1207bd2e8>,
#  'individualists': <gensim.models.keyedvectors.Vocab at 0x1207bd320>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x1207bd358>,
#  'lysander': <gensim.models.keyedvectors.Vocab at 0x1207bd3c8>,
#  'spooner': <gensim.models.keyedvectors.Vocab at 0x1207bd518>,
#  'stephen': <gensim.models.keyedvectors.Vocab at 0x1207bd550>,
#  'pearl': <gensim.models.keyedvectors.Vocab at 0x1207bd588>,
#  'andrews': <gensim.models.keyedvectors.Vocab at 0x1207bd5c0>,
#  'victor': <gensim.models.keyedvectors.Vocab at 0x1207bd5f8>,
#  'yarros': <gensim.models.keyedvectors.Vocab at 0x1207bd630>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x1207bd668>,
#  'mikhail': <gensim.models.keyedvectors.Vocab at 0x1207bd6a0>,
#  'bakunin': <gensim.models.keyedvectors.Vocab at 0x1207bd748>,
#  'harsh': <gensim.models.keyedvectors.Vocab at 0x1207bd7f0>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x1207bd828>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x1207bd860>,
#  'revolutions': <gensim.models.keyedvectors.Vocab at 0x1207bd8d0>,
#  'twenty': <gensim.models.keyedvectors.Vocab at 0x1207bd940>,
#  'workingmen': <gensim.models.keyedvectors.Vocab at 0x1207bd978>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x1207bda58>,
#  'european': <gensim.models.keyedvectors.Vocab at 0x1207bda90>,
#  'revolutionary': <gensim.models.keyedvectors.Vocab at 0x1207bdac8>,
#  'currents': <gensim.models.keyedvectors.Vocab at 0x1207bdb00>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1207bdb38>,
#  'genuine': <gensim.models.keyedvectors.Vocab at 0x1207bdb70>,
#  'links': <gensim.models.keyedvectors.Vocab at 0x1207bdba8>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1207bdc50>,
#  'karl': <gensim.models.keyedvectors.Vocab at 0x1207bdcc0>,
#  'marx': <gensim.models.keyedvectors.Vocab at 0x1207bddd8>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x1207bdef0>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x1207bdf28>,
#  'elected': <gensim.models.keyedvectors.Vocab at 0x120556f60>,
#  'succeeding': <gensim.models.keyedvectors.Vocab at 0x120556390>,
#  'council': <gensim.models.keyedvectors.Vocab at 0x120556470>,
#  'objections': <gensim.models.keyedvectors.Vocab at 0x120556780>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x120556828>,
#  'mutualists': <gensim.models.keyedvectors.Vocab at 0x1205568d0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x120556908>,
#  'statism': <gensim.models.keyedvectors.Vocab at 0x1205569b0>,
#  'shortly': <gensim.models.keyedvectors.Vocab at 0x120556a20>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x120556cc0>,
#  'joined': <gensim.models.keyedvectors.Vocab at 0x11fa14fd0>,
#  'polarised': <gensim.models.keyedvectors.Vocab at 0x11fa144a8>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x11fa14940>,
#  'camps': <gensim.models.keyedvectors.Vocab at 0x11fa14ac8>,
#  'respective': <gensim.models.keyedvectors.Vocab at 0x1205a4b38>,
#  'figureheads': <gensim.models.keyedvectors.Vocab at 0x1205a4cc0>,
#  'clearest': <gensim.models.keyedvectors.Vocab at 0x1205a40f0>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x1205a4438>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x1205a45f8>,
#  'strategy': <gensim.models.keyedvectors.Vocab at 0x1205a4828>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1205a4860>,
#  'favoured': <gensim.models.keyedvectors.Vocab at 0x1205a4908>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x120734438>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x120734470>,
#  'economical': <gensim.models.keyedvectors.Vocab at 0x120734668>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x1207346d8>,
#  'capitalism': <gensim.models.keyedvectors.Vocab at 0x1207348d0>,
#  'interfering': <gensim.models.keyedvectors.Vocab at 0x120734978>,
#  'parliamentary': <gensim.models.keyedvectors.Vocab at 0x1207349b0>,
#  'agitation': <gensim.models.keyedvectors.Vocab at 0x1207349e8>,
#  'focused': <gensim.models.keyedvectors.Vocab at 0x120734b38>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x120734b70>,
#  'characterised': <gensim.models.keyedvectors.Vocab at 0x120734cc0>,
#  'predicted': <gensim.models.keyedvectors.Vocab at 0x120734d68>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x120734dd8>,
#  'marxist': <gensim.models.keyedvectors.Vocab at 0x120734e48>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x120734f28>,
#  'gained': <gensim.models.keyedvectors.Vocab at 0x120734048>,
#  'leaders': <gensim.models.keyedvectors.Vocab at 0x1207340b8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x120734128>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x120734358>,
#  'ruling': <gensim.models.keyedvectors.Vocab at 0x11f8ba828>,
#  'fought': <gensim.models.keyedvectors.Vocab at 0x11f8ba390>,
#  'climaxed': <gensim.models.keyedvectors.Vocab at 0x11e76fda0>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x11f5d5630>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x11f5d58d0>,
#  'hague': <gensim.models.keyedvectors.Vocab at 0x11f930b38>,
#  'congress': <gensim.models.keyedvectors.Vocab at 0x11f9300b8>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x12057a0f0>,
#  'cited': <gensim.models.keyedvectors.Vocab at 0x12057a160>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x12057a358>,
#  'marxists': <gensim.models.keyedvectors.Vocab at 0x12057a3c8>,
#  'democratic': <gensim.models.keyedvectors.Vocab at 0x12057a5c0>,
#  'socialism': <gensim.models.keyedvectors.Vocab at 0x12057a5f8>,
#  'distinct': <gensim.models.keyedvectors.Vocab at 0x12057a860>,
#  'organisations': <gensim.models.keyedvectors.Vocab at 0x12057a898>,
#  'rival': <gensim.models.keyedvectors.Vocab at 0x12057aa90>,
#  'internationals': <gensim.models.keyedvectors.Vocab at 0x12057aac8>,
#  'peter': <gensim.models.keyedvectors.Vocab at 0x12057ac50>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x12057ac88>,
#  'associating': <gensim.models.keyedvectors.Vocab at 0x12057acc0>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x11f904240>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x11f904278>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x11f9048d0>,
#  'collectivism': <gensim.models.keyedvectors.Vocab at 0x120585f60>,
#  'embraced': <gensim.models.keyedvectors.Vocab at 0x120585128>,
#  'communist': <gensim.models.keyedvectors.Vocab at 0x120585198>,
#  'concepts': <gensim.models.keyedvectors.Vocab at 0x120585390>,
#  'communists': <gensim.models.keyedvectors.Vocab at 0x1205853c8>,
#  'owned': <gensim.models.keyedvectors.Vocab at 0x120585438>,
#  'collectively': <gensim.models.keyedvectors.Vocab at 0x1205854e0>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x1205855c0>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x120585828>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x120585940>,
#  'jacque': <gensim.models.keyedvectors.Vocab at 0x120585978>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x120585a90>,
#  'unlike': <gensim.models.keyedvectors.Vocab at 0x120585cf8>,
#  'worker': <gensim.models.keyedvectors.Vocab at 0x120585e80>,
#  'satisfaction': <gensim.models.keyedvectors.Vocab at 0x12087e7f0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x12087e080>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x12087e0b8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x12087e0f0>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x12087e160>,
#  'announced': <gensim.models.keyedvectors.Vocab at 0x12087e198>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x12087e1d0>,
#  'journal': <gensim.models.keyedvectors.Vocab at 0x12087e208>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x12087e240>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x12087e278>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x12087e2e8>,
#  'theorist': <gensim.models.keyedvectors.Vocab at 0x12087e320>,
#  'outlined': <gensim.models.keyedvectors.Vocab at 0x12087e358>,
#  'conquest': <gensim.models.keyedvectors.Vocab at 0x12087e390>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x12087e3c8>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x12087e400>,
#  'factories': <gensim.models.keyedvectors.Vocab at 0x12087e438>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x12087e470>,
#  'operation': <gensim.models.keyedvectors.Vocab at 0x12087e4a8>,
#  'beneficial': <gensim.models.keyedvectors.Vocab at 0x12087e4e0>,
#  'illustrated': <gensim.models.keyedvectors.Vocab at 0x12087e518>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x12087e550>,
#  'evolution': <gensim.models.keyedvectors.Vocab at 0x12087e588>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x12087e5c0>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x12087e5f8>,
#  'emma': <gensim.models.keyedvectors.Vocab at 0x12087e6a0>,
#  'goldman': <gensim.models.keyedvectors.Vocab at 0x12087e6d8>,
#  'alexander': <gensim.models.keyedvectors.Vocab at 0x12087e780>,
#  'berkman': <gensim.models.keyedvectors.Vocab at 0x12087e7b8>,
#  'anarcho': <gensim.models.keyedvectors.Vocab at 0x12087e828>,
#  'syndicalist': <gensim.models.keyedvectors.Vocab at 0x12087e860>,
#  'below': <gensim.models.keyedvectors.Vocab at 0x12087e8d0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x12087e978>,
#  'objective': <gensim.models.keyedvectors.Vocab at 0x12087ec18>,
#  'isaac': <gensim.models.keyedvectors.Vocab at 0x12087ec50>,
#  'puente': <gensim.models.keyedvectors.Vocab at 0x12087ecc0>,
#  'comunismo': <gensim.models.keyedvectors.Vocab at 0x12087ecf8>,
#  'libertario': <gensim.models.keyedvectors.Vocab at 0x12087ed68>,
#  'spanish': <gensim.models.keyedvectors.Vocab at 0x12087eda0>,
#  'cnt': <gensim.models.keyedvectors.Vocab at 0x12087edd8>,
#  'manifesto': <gensim.models.keyedvectors.Vocab at 0x12087ee48>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x12087ee80>,
#  'disliked': <gensim.models.keyedvectors.Vocab at 0x12087ef28>,
#  'merging': <gensim.models.keyedvectors.Vocab at 0x12087ef60>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x12087ef98>,
#  'maintained': <gensim.models.keyedvectors.Vocab at 0x12087efd0>,
#  'abolition': <gensim.models.keyedvectors.Vocab at 0x120870048>,
#  'consistent': <gensim.models.keyedvectors.Vocab at 0x120870080>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1208700f0>,
#  'professing': <gensim.models.keyedvectors.Vocab at 0x120870160>,
#  'publishing': <gensim.models.keyedvectors.Vocab at 0x1208701d0>,
#  'pseudo': <gensim.models.keyedvectors.Vocab at 0x120870240>,
#  'propaganda': <gensim.models.keyedvectors.Vocab at 0x120870278>,
#  'deed': <gensim.models.keyedvectors.Vocab at 0x1208702b0>,
#  'johann': <gensim.models.keyedvectors.Vocab at 0x120870320>,
#  'outspoken': <gensim.models.keyedvectors.Vocab at 0x120870390>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x1208703c8>,
#  'portrayed': <gensim.models.keyedvectors.Vocab at 0x120870400>,
#  'dangerous': <gensim.models.keyedvectors.Vocab at 0x120870438>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1208704a8>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x1208704e0>,
#  'acts': <gensim.models.keyedvectors.Vocab at 0x120870518>,
#  'riots': <gensim.models.keyedvectors.Vocab at 0x120870550>,
#  'assassinations': <gensim.models.keyedvectors.Vocab at 0x1208705f8>,
#  'insurrections': <gensim.models.keyedvectors.Vocab at 0x120870630>,
#  'terrorism': <gensim.models.keyedvectors.Vocab at 0x120870668>,
#  'revolutionaries': <gensim.models.keyedvectors.Vocab at 0x1208706a0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1208706d8>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x120870748>,
#  'bombings': <gensim.models.keyedvectors.Vocab at 0x120870780>,
#  'heads': <gensim.models.keyedvectors.Vocab at 0x1208707b8>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x1208707f0>,
#  'actions': <gensim.models.keyedvectors.Vocab at 0x120870860>,
#  'advocates': <gensim.models.keyedvectors.Vocab at 0x1208708d0>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x120870940>,
#  'existing': <gensim.models.keyedvectors.Vocab at 0x120870978>,
#  'quickest': <gensim.models.keyedvectors.Vocab at 0x1208709b0>,
#  'radically': <gensim.models.keyedvectors.Vocab at 0x1208709e8>,
#  'overthrown': <gensim.models.keyedvectors.Vocab at 0x120870a58>,
#  'annihilation': <gensim.models.keyedvectors.Vocab at 0x120870a90>,
#  'exponents': <gensim.models.keyedvectors.Vocab at 0x120870ac8>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x120870b70>,
#  'massacres': <gensim.models.keyedvectors.Vocab at 0x120870ba8>,
#  'enemies': <gensim.models.keyedvectors.Vocab at 0x120870be0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x120870c50>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x120870c88>,
#  'motion': <gensim.models.keyedvectors.Vocab at 0x120870cc0>,
#  'preferred': <gensim.models.keyedvectors.Vocab at 0x120870d30>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x120870d68>,
#  'dynamite': <gensim.models.keyedvectors.Vocab at 0x120870da0>,
#  'earned': <gensim.models.keyedvectors.Vocab at 0x120870e48>,
#  'moniker': <gensim.models.keyedvectors.Vocab at 0x120870e80>,
#  'consensus': <gensim.models.keyedvectors.Vocab at 0x120870eb8>,
#  'legitimacy': <gensim.models.keyedvectors.Vocab at 0x120870ef0>,
#  'utility': <gensim.models.keyedvectors.Vocab at 0x120870f28>,
#  'errico': <gensim.models.keyedvectors.Vocab at 0x120870f60>,
#  'malatesta': <gensim.models.keyedvectors.Vocab at 0x120870f98>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x120838fd0>,
#  'desirable': <gensim.models.keyedvectors.Vocab at 0x120838a58>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x120838ac8>,
#  'settings': <gensim.models.keyedvectors.Vocab at 0x120838b00>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x120838b38>,
#  'denounced': <gensim.models.keyedvectors.Vocab at 0x120838b70>,
#  'refuted': <gensim.models.keyedvectors.Vocab at 0x120838ba8>,
#  'identified': <gensim.models.keyedvectors.Vocab at 0x120838be0>,
#  'pacifist': <gensim.models.keyedvectors.Vocab at 0x120838c50>,
#  'nonviolence': <gensim.models.keyedvectors.Vocab at 0x120838cc0>,
#  'leo': <gensim.models.keyedvectors.Vocab at 0x120838da0>,
#  'tolstoy': <gensim.models.keyedvectors.Vocab at 0x120838e10>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x120838eb8>,
#  'viewed': <gensim.models.keyedvectors.Vocab at 0x120838f60>,
#  'christian': <gensim.models.keyedvectors.Vocab at 0x1208389b0>,
#  'notable': <gensim.models.keyedvectors.Vocab at 0x120838908>,
#  'exponent': <gensim.models.keyedvectors.Vocab at 0x120838048>,
#  'nonviolent': <gensim.models.keyedvectors.Vocab at 0x1208380b8>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x1208380f0>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x120838160>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x1208382b0>,
#  'flag': <gensim.models.keyedvectors.Vocab at 0x120838358>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x120838390>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x120838470>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x120838518>,
#  'syndicalism': <gensim.models.keyedvectors.Vocab at 0x1208385c0>,
#  'seeking': <gensim.models.keyedvectors.Vocab at 0x1208385f8>,
#  'overthrow': <gensim.models.keyedvectors.Vocab at 0x120838630>,
#  'institute': <gensim.models.keyedvectors.Vocab at 0x120838668>,
#  'controlled': <gensim.models.keyedvectors.Vocab at 0x1208386a0>,
#  'pursued': <gensim.models.keyedvectors.Vocab at 0x120838978>,
#  'industrial': <gensim.models.keyedvectors.Vocab at 0x12052bc50>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x12052bf28>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x12060a4e0>,
#  'syndicalists': <gensim.models.keyedvectors.Vocab at 0x12060a7b8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x12060a828>,
#  'repression': <gensim.models.keyedvectors.Vocab at 0x12060aa58>,
#  'reemerged': <gensim.models.keyedvectors.Vocab at 0x12060aa90>,
#  'influencing': <gensim.models.keyedvectors.Vocab at 0x12060abe0>,
#  'bourses': <gensim.models.keyedvectors.Vocab at 0x12060add8>,
#  'travails': <gensim.models.keyedvectors.Vocab at 0x12060af98>,
#  'unions': <gensim.models.keyedvectors.Vocab at 0x12060a0b8>,
#  'conf': <gensim.models.keyedvectors.Vocab at 0x11fa76080>,
#  'ration': <gensim.models.keyedvectors.Vocab at 0x11fa76668>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x11fa76908>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x11fa76a20>,
#  'rale': <gensim.models.keyedvectors.Vocab at 0x11fa76b70>,
#  'du': <gensim.models.keyedvectors.Vocab at 0x11fa76ba8>,
#  'travail': <gensim.models.keyedvectors.Vocab at 0x11f93cd30>,
#  'confederation': <gensim.models.keyedvectors.Vocab at 0x11f93c048>,
#  'cgt': <gensim.models.keyedvectors.Vocab at 0x11f93c320>,
#  'formed': <gensim.models.keyedvectors.Vocab at 0x11f93c518>,
#  'emile': <gensim.models.keyedvectors.Vocab at 0x11f93c828>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x11f93cbe0>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x11f98a588>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x11f98a9e8>,
#  'bolshevism': <gensim.models.keyedvectors.Vocab at 0x11f98aac8>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x11f98ab38>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x11f98add8>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x11f98aef0>,
#  'remained': <gensim.models.keyedvectors.Vocab at 0x11f98a1d0>,
#  'spain': <gensim.models.keyedvectors.Vocab at 0x11f98a390>,
#  'mid': <gensim.models.keyedvectors.Vocab at 0x11f98a470>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x11f967e48>,
#  'iww': <gensim.models.keyedvectors.Vocab at 0x11f967780>,
#  'founded': <gensim.models.keyedvectors.Vocab at 0x11f967b00>,
#  'espoused': <gensim.models.keyedvectors.Vocab at 0x12072f6a0>,
#  'unionism': <gensim.models.keyedvectors.Vocab at 0x12072f7b8>,
#  'sought': <gensim.models.keyedvectors.Vocab at 0x12072f898>,
#  'usher': <gensim.models.keyedvectors.Vocab at 0x12072f908>,
#  'stateless': <gensim.models.keyedvectors.Vocab at 0x12072f978>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x12072f9b0>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x12072fba8>,
#  'explicitly': <gensim.models.keyedvectors.Vocab at 0x12072fbe0>,
#  'rank': <gensim.models.keyedvectors.Vocab at 0x12072fcc0>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x12072fd30>,
#  'democracy': <gensim.models.keyedvectors.Vocab at 0x12072fe80>,
#  'embodying': <gensim.models.keyedvectors.Vocab at 0x12072fef0>,
#  'inspired': <gensim.models.keyedvectors.Vocab at 0x12072ff60>,
#  'anglophone': <gensim.models.keyedvectors.Vocab at 0x12072ff98>,
#  'reads': <gensim.models.keyedvectors.Vocab at 0x12072ffd0>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x12072f0f0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x12072f128>,
#  'politicians': <gensim.models.keyedvectors.Vocab at 0x12072f198>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x12072f278>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x12072f3c8>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x12072f438>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x12072f470>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x12072f550>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x12072f5c0>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1205382e8>,
#  'unity': <gensim.models.keyedvectors.Vocab at 0x1205383c8>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x120538908>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x120538940>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x120538ac8>,
#  'federations': <gensim.models.keyedvectors.Vocab at 0x120538be0>,
#  'successful': <gensim.models.keyedvectors.Vocab at 0x120538c50>,
#  'confederaci': <gensim.models.keyedvectors.Vocab at 0x120538dd8>,
#  'nacional': <gensim.models.keyedvectors.Vocab at 0x1205c9dd8>,
#  'del': <gensim.models.keyedvectors.Vocab at 0x1205c9eb8>,
#  'trabajo': <gensim.models.keyedvectors.Vocab at 0x1205c90b8>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x1205c90f0>,
#  'politics': <gensim.models.keyedvectors.Vocab at 0x1205c9208>,
#  'membership': <gensim.models.keyedvectors.Vocab at 0x1205c9748>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x12074a438>,
#  'played': <gensim.models.keyedvectors.Vocab at 0x12074a240>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x12074a2b0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x12074a400>,
#  'ricardo': <gensim.models.keyedvectors.Vocab at 0x12074a4a8>,
#  'flores': <gensim.models.keyedvectors.Vocab at 0x12074a630>,
#  'mag': <gensim.models.keyedvectors.Vocab at 0x12074a6a0>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x12074a7b8>,
#  'figures': <gensim.models.keyedvectors.Vocab at 0x12074a7f0>,
#  'mexican': <gensim.models.keyedvectors.Vocab at 0x12074a8d0>,
#  'latin': <gensim.models.keyedvectors.Vocab at 0x12074a908>,
#  'influenced': <gensim.models.keyedvectors.Vocab at 0x12074a940>,
#  'extending': <gensim.models.keyedvectors.Vocab at 0x12074a9b0>,
#  'zapatista': <gensim.models.keyedvectors.Vocab at 0x12074aac8>,
#  'rebellion': <gensim.models.keyedvectors.Vocab at 0x12074ab00>,
#  'factory': <gensim.models.keyedvectors.Vocab at 0x12074abe0>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x12074ac50>,
#  'argentina': <gensim.models.keyedvectors.Vocab at 0x12074acf8>,
#  'berlin': <gensim.models.keyedvectors.Vocab at 0x12074ad30>,
#  'successor': <gensim.models.keyedvectors.Vocab at 0x12074ad68>,
#  'contemporary': <gensim.models.keyedvectors.Vocab at 0x12074ae80>,
#  'continues': <gensim.models.keyedvectors.Vocab at 0x12074aeb8>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x12074afd0>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x12074a048>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x12074a080>,
#  'organised': <gensim.models.keyedvectors.Vocab at 0x12074a0b8>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x12074a128>,
#  'claims': <gensim.models.keyedvectors.Vocab at 0x11fa8bc50>,
#  'paid': <gensim.models.keyedvectors.Vocab at 0x11fa8bda0>,
#  'votes': <gensim.models.keyedvectors.Vocab at 0x11fa8b2e8>,
#  'elections': <gensim.models.keyedvectors.Vocab at 0x11fa8b860>,
#  'solidarity': <gensim.models.keyedvectors.Vocab at 0x11fa8b9e8>,
#  'alliance': <gensim.models.keyedvectors.Vocab at 0x11f8a9cf8>,
#  'uk': <gensim.models.keyedvectors.Vocab at 0x11f8a9fd0>,
#  'federation': <gensim.models.keyedvectors.Vocab at 0x11f8a9908>,
#  'unionist': <gensim.models.keyedvectors.Vocab at 0x11f8a9898>,
#  'exists': <gensim.models.keyedvectors.Vocab at 0x1207266a0>,
#  'claiming': <gensim.models.keyedvectors.Vocab at 0x120726240>,
#  'critics': <gensim.models.keyedvectors.Vocab at 0x1207262b0>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x120726320>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x120726438>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x120726470>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x120726630>,
#  'leftist': <gensim.models.keyedvectors.Vocab at 0x120726668>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x120726978>,
#  'oppressive': <gensim.models.keyedvectors.Vocab at 0x1207269e8>,
#  'workplace': <gensim.models.keyedvectors.Vocab at 0x120726ac8>,
#  'uphold': <gensim.models.keyedvectors.Vocab at 0x120726b00>,
#  'russian': <gensim.models.keyedvectors.Vocab at 0x120726b38>,
#  'seismic': <gensim.models.keyedvectors.Vocab at 0x120726b70>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x120726ba8>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x120726c88>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x120726da0>,
#  'bolsheviks': <gensim.models.keyedvectors.Vocab at 0x120726f28>,
#  'february': <gensim.models.keyedvectors.Vocab at 0x120726f98>,
#  'october': <gensim.models.keyedvectors.Vocab at 0x120553c88>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x120553f28>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x120553f60>,
#  'bolshevik': <gensim.models.keyedvectors.Vocab at 0x120553be0>,
#  'coup': <gensim.models.keyedvectors.Vocab at 0x1208520b8>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x120852198>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x120852208>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x120852278>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x120852320>,
#  'opposition': <gensim.models.keyedvectors.Vocab at 0x1208523c8>,
#  'culminated': <gensim.models.keyedvectors.Vocab at 0x120852400>,
#  'kronstadt': <gensim.models.keyedvectors.Vocab at 0x120852470>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x120852518>,
#  'russia': <gensim.models.keyedvectors.Vocab at 0x120852588>,
#  'imprisoned': <gensim.models.keyedvectors.Vocab at 0x120852710>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x120852748>,
#  'underground': <gensim.models.keyedvectors.Vocab at 0x120852780>,
#  'victorious': <gensim.models.keyedvectors.Vocab at 0x120852860>,
#  'ukraine': <gensim.models.keyedvectors.Vocab at 0x120852898>,
#  'whites': <gensim.models.keyedvectors.Vocab at 0x120852940>,
#  'peasant': <gensim.models.keyedvectors.Vocab at 0x120852a20>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x120852a58>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x120852b00>,
#  'nestor': <gensim.models.keyedvectors.Vocab at 0x120852cc0>,
#  'makhno': <gensim.models.keyedvectors.Vocab at 0x120852d68>,
#  'expelled': <gensim.models.keyedvectors.Vocab at 0x120852ef0>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x120852fd0>,
#  'amongst': <gensim.models.keyedvectors.Vocab at 0x120853f28>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x120853fd0>,
#  'agitating': <gensim.models.keyedvectors.Vocab at 0x120853048>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x120853160>,
#  'policy': <gensim.models.keyedvectors.Vocab at 0x120853278>,
#  'suppression': <gensim.models.keyedvectors.Vocab at 0x1208532e8>,
#  'uprising': <gensim.models.keyedvectors.Vocab at 0x120853358>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x120853390>,
#  'accounts': <gensim.models.keyedvectors.Vocab at 0x1208534a8>,
#  'experiences': <gensim.models.keyedvectors.Vocab at 0x1208534e0>,
#  'aiming': <gensim.models.keyedvectors.Vocab at 0x120853518>,
#  'expose': <gensim.models.keyedvectors.Vocab at 0x120853550>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x1208535c0>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x120853668>,
#  'predictions': <gensim.models.keyedvectors.Vocab at 0x1208536a0>,
#  'consequences': <gensim.models.keyedvectors.Vocab at 0x120853748>,
#  'proved': <gensim.models.keyedvectors.Vocab at 0x120853780>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x1208537f0>,
#  'victory': <gensim.models.keyedvectors.Vocab at 0x120853908>,
#  'resulting': <gensim.models.keyedvectors.Vocab at 0x120853a58>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x120853a90>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x120853ac8>,
#  'internationally': <gensim.models.keyedvectors.Vocab at 0x120853b38>,
#  'activists': <gensim.models.keyedvectors.Vocab at 0x120853c18>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x120853c50>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x120853cc0>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x120853da0>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x120853e10>,
#  'expense': <gensim.models.keyedvectors.Vocab at 0x120853e48>,
#  'socialist': <gensim.models.keyedvectors.Vocab at 0x120853eb8>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x1207774e0>,
#  'realign': <gensim.models.keyedvectors.Vocab at 0x1207776d8>,
#  'themselves': <gensim.models.keyedvectors.Vocab at 0x120777710>,
#  'towards': <gensim.models.keyedvectors.Vocab at 0x1207777b8>,
#  'paris': <gensim.models.keyedvectors.Vocab at 0x120777978>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x120777a90>,
#  'exiles': <gensim.models.keyedvectors.Vocab at 0x120777ac8>,
#  'concluded': <gensim.models.keyedvectors.Vocab at 0x120777b38>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x120777cf8>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x120777ef0>,
#  'forms': <gensim.models.keyedvectors.Vocab at 0x120777fd0>,
#  'organisational': <gensim.models.keyedvectors.Vocab at 0x120777198>,
#  'platform': <gensim.models.keyedvectors.Vocab at 0x1207771d0>,
#  'inspire': <gensim.models.keyedvectors.Vocab at 0x120777208>,
#  'theoretical': <gensim.models.keyedvectors.Vocab at 0x11fabb588>,
#  'tactical': <gensim.models.keyedvectors.Vocab at 0x11fabb7b8>,
#  'collective': <gensim.models.keyedvectors.Vocab at 0x11fabb908>,
#  'responsibility': <gensim.models.keyedvectors.Vocab at 0x11fabbac8>,
#  'federalism': <gensim.models.keyedvectors.Vocab at 0x11fabb2e8>,
#  'platformist': <gensim.models.keyedvectors.Vocab at 0x1208bc080>,
#  'ireland': <gensim.models.keyedvectors.Vocab at 0x1208bc0b8>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x1208bc128>,
#  'eastern': <gensim.models.keyedvectors.Vocab at 0x1208bc1d0>,
#  'northeastern': <gensim.models.keyedvectors.Vocab at 0x1208bc208>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x1208bc240>,
#  'bordering': <gensim.models.keyedvectors.Vocab at 0x1208bc2b0>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x1208bc4a8>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x1208bc4e0>,
#  'fascism': <gensim.models.keyedvectors.Vocab at 0x1208bc518>,
#  'construct': <gensim.models.keyedvectors.Vocab at 0x1208bc588>,
#  'armoured': <gensim.models.keyedvectors.Vocab at 0x1208bc5c0>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x1208bc5f8>,
#  'fascists': <gensim.models.keyedvectors.Vocab at 0x1208bc630>,
#  'collectivised': <gensim.models.keyedvectors.Vocab at 0x1208bc6a0>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x1208bc710>,
#  'dynamics': <gensim.models.keyedvectors.Vocab at 0x1208bc780>,
#  'transformed': <gensim.models.keyedvectors.Vocab at 0x1208bc7b8>,
#  'rise': <gensim.models.keyedvectors.Vocab at 0x1208bc860>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x1208bc8d0>,
#  'faced': <gensim.models.keyedvectors.Vocab at 0x1208bc940>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x1208bc978>,
#  'choices': <gensim.models.keyedvectors.Vocab at 0x1208bc9b0>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x1208bca20>,
#  'fronts': <gensim.models.keyedvectors.Vocab at 0x1208bca58>,
#  'reformist': <gensim.models.keyedvectors.Vocab at 0x1208bca90>,
#  'democrats': <gensim.models.keyedvectors.Vocab at 0x1208bcac8>,
#  'soviet': <gensim.models.keyedvectors.Vocab at 0x1208bcbe0>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x1208bccc0>,
#  'fascist': <gensim.models.keyedvectors.Vocab at 0x1208bccf8>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x1208bcd68>,
#  'luigi': <gensim.models.keyedvectors.Vocab at 0x1208bce80>,
#  'fabbri': <gensim.models.keyedvectors.Vocab at 0x1205df438>,
#  'exile': <gensim.models.keyedvectors.Vocab at 0x1205df8d0>,
#  'italian': <gensim.models.keyedvectors.Vocab at 0x1205dfa90>,
#  'arguing': <gensim.models.keyedvectors.Vocab at 0x1205dfb70>,
#  ...}

# %%
len(model.wv.vocab)
# Out:
# 135335

# %%
model['class']
# Out:
# array([ 0.5360907 , -0.441089  ,  0.89019054,  2.0754266 ,  1.2878581 ,
#         1.128447  ,  0.8118017 ,  1.8491855 , -0.2833099 ,  0.5856371 ,
#         2.4622817 , -2.8441482 ,  1.1643565 ,  0.19691107, -0.49996018,
#        -0.56271577, -1.233788  ,  2.793063  ,  2.2169101 ,  0.38130733,
#         2.9793766 , -2.139408  , -1.7064501 ,  2.5583453 , -0.35653237,
#         0.3795161 , -0.6144545 ,  1.0386775 ,  0.11489288, -0.6938939 ,
#         0.77557874,  0.8322609 , -2.9366553 ,  0.6844214 , -0.9657359 ,
#         0.8125163 ,  0.832762  , -1.0628809 , -0.08384193, -0.25565064,
#         2.292351  , -0.36269534, -0.40088478,  0.18820508,  0.5723222 ,
#        -0.03997412,  1.1108757 ,  0.42575684,  0.07557081, -1.24541   ,
#         1.2262676 ,  1.1068904 , -0.76907027,  0.45894733,  1.391429  ,
#         0.88877314, -1.6303163 , -0.9278133 ,  0.9312615 , -0.5273765 ,
#         2.7569191 , -0.18381362,  1.2189696 , -2.4065514 , -0.7709806 ,
#        -2.20651   ,  2.300374  ,  0.13221838, -1.1859095 , -0.11636399,
#         1.9091995 , -0.4311784 , -1.92525   , -0.92048115, -2.150894  ,
#        -2.0500898 ,  0.68855625, -1.5436639 , -1.12528   , -0.6311764 ,
#        -0.48818105, -0.8057665 ,  0.8063338 , -1.8889282 ,  1.6368763 ,
#         1.4795991 ,  2.1457262 ,  0.4858323 ,  0.71366113, -2.0212681 ,
#        -0.61056024,  0.11607853,  1.1450863 , -1.333911  ,  1.0565417 ,
#         0.47309312,  1.9217955 , -1.2211467 ,  0.06463908, -4.175649  ],
#       dtype=float32)

# %%
model["king"]
# Out:
# array([ 3.4896576e+00,  4.5028896e+00, -2.9649706e+00,  2.4145271e-01,
#         1.0370830e+00,  2.8155174e-03,  6.8447061e+00,  4.0353932e+00,
#        -3.3325212e+00, -3.7365904e+00], dtype=float32)

# %%
model.most_similar(positive=["king"],topn=10)
# Out:
# [('queen', 0.7308107614517212),
#  ('prince', 0.7306633591651917),
#  ('emperor', 0.7095600366592407),
#  ('throne', 0.6926149725914001),
#  ('kings', 0.6807711124420166),
#  ('pope', 0.677489161491394),
#  ('vii', 0.6689014434814453),
#  ('regent', 0.6543641686439514),
#  ('elector', 0.6538203954696655),
#  ('aragon', 0.6518200039863586)]

# %%
model["bands"]
# Out:
# array([ 6.0311061e-01, -5.0748104e-01,  3.4381318e-01,  3.6617127e-01,
#        -7.8092879e-01, -9.5004946e-02, -1.5865935e+00,  9.6291763e-01,
#        -2.5482273e+00,  2.5095200e-02,  1.0947617e+00, -1.4418622e+00,
#        -2.4503334e+00, -1.1739563e+00,  1.8983934e+00,  9.7577530e-01,
#        -1.5667801e-01, -3.2414126e+00,  6.7157078e-01,  4.9652553e-01,
#         8.5582927e-02, -2.0940475e+00, -1.2269276e+00, -5.3546399e-01,
#        -6.5166771e-01, -1.0734159e+00, -5.0408578e-01, -2.8151851e+00,
#         6.1835307e-01, -9.4884515e-01,  1.1460555e+00, -3.4539431e-01,
#         2.0269456e+00,  1.1998639e-01,  2.1026801e-01,  1.1780379e+00,
#         5.5140513e-01, -2.3460257e+00,  5.9057463e-02,  9.9359101e-01,
#         3.7891510e+00,  1.5199071e+00,  4.6139100e-01,  5.9062759e-03,
#         8.8992655e-02, -1.2519975e+00,  1.3357881e-02, -1.1179926e+00,
#         1.2184165e+00, -1.2246690e+00, -2.9598007e-01,  1.3065239e+00,
#        -8.1030434e-01,  9.1326821e-01, -4.2553309e-02, -8.1264144e-01,
#        -2.2345293e+00,  3.1348231e-01,  5.7716399e-01, -1.7375833e-01,
#         5.0893360e-01,  6.6261458e-01, -8.9574534e-01,  8.1170976e-01,
#         2.4338774e-01, -1.0284543e+00,  1.2812686e+00, -1.2523929e+00,
#        -2.9210255e-01,  9.1845617e-03,  1.5633116e+00,  2.8991833e-01,
#         2.2984974e+00,  1.2695974e+00, -8.5178095e-01,  2.2089839e-01,
#         2.9873842e-01,  5.6911039e-01,  1.3413595e-01,  5.3333032e-01,
#        -1.0117425e+00, -1.0540098e+00,  7.2163618e-01,  1.2331738e+00,
#        -2.1450093e+00,  1.0680150e+00,  7.9605639e-01, -1.0745543e+00,
#        -1.1571469e+00,  2.3377691e-01, -8.1259407e-02, -1.4858676e-01,
#        -1.2002751e+00,  2.0170422e+00, -1.7433232e+00, -3.6940932e-01,
#         6.8123156e-01,  1.3919567e-03, -1.5025740e+00, -2.2732785e+00],
#       dtype=float32)

# %%
len(model.wv.vocab)

# %%
model.wv.vocab

# %%
model["anarchism"]

# %%
model.most_similar(positive=['woman', 'king'], negative=['man'], topn=10)
# Out:
# [('queen', 0.6530534029006958),
#  ('empress', 0.6200270652770996),
#  ('daughter', 0.6076130867004395),
#  ('son', 0.6041483879089355),
#  ('prince', 0.6018291115760803),
#  ('emperor', 0.5962084531784058),
#  ('isabella', 0.5913447141647339),
#  ('wife', 0.5887458920478821),
#  ('throne', 0.5838378071784973),
#  ('aldona', 0.5838095545768738)]

# %%
model.most_similar(['man'])
# Out:
# [('woman', 0.7294749021530151),
#  ('girl', 0.6839900612831116),
#  ('creature', 0.6361184120178223),
#  ('person', 0.6000561714172363),
#  ('boy', 0.5886635780334473),
#  ('evil', 0.5747945308685303),
#  ('soul', 0.5654525756835938),
#  ('stranger', 0.5652815699577332),
#  ('god', 0.561619758605957),
#  ('beast', 0.5516027212142944)]

# %%
model.save('text8_1.model')

# %%
model.wv.save_word2vec_format('text2_2.model.bin', binary=True)

# %%
model1 = word2vec.KeyedVectors.load_word2vec_format('text2_2.model.bin', binary=True)

# %%
model1["english"]

# %%
model1.most_similar(['girl', 'father'], ['boy'], topn=3)
# Out:
# [('mother', 0.788677990436554),
#  ('wife', 0.7215999960899353),
#  ('grandmother', 0.700046181678772)]

# %%
more_examples = ["he is she", "big bigger bad", "going went being"]

# %%
for example in more_examples:
    a, b, x = example.split()
    predicted = model1.most_similar([x, b], [a])[0][0]
    print ("'%s' is to '%s' as '%s' is to '%s'" % (a, b, x, predicted))
# Out:
# 'he' is to 'is' as 'she' is to 'remains'
# 'big' is to 'bigger' as 'bad' is to 'worse'
# 'going' is to 'went' as 'being' is to 'was'

# %%
model_org = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-20962ef2b626> in <module>()
# ----> 1 model_org = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
#
# /Users/junior/anaconda/lib/python3.6/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     203
#     204         logger.info("loading projection weights from %s", fname)
# --> 205         with utils.smart_open(fname) as fin:
#     206             header = utils.to_unicode(fin.readline(), encoding=encoding)
#     207             vocab_size, vector_size = map(int, header.split())  # throws for invalid file format
#
# /Users/junior/anaconda/lib/python3.6/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     138             # local files -- both read & write supported
#     139             # compression, if any, is determined by the filename extension (.gz, .bz2)
# --> 140             return file_smart_open(parsed_uri.uri_path, mode)
#     141         elif parsed_uri.scheme in ("s3", "s3n", "s3u"):
#     142             kwargs = {}
#
# /Users/junior/anaconda/lib/python3.6/site-packages/smart_open/smart_open_lib.py in file_smart_open(fname, mode)
#     642
#     643     """
# --> 644     return compression_wrapper(open(fname, mode), fname, mode)
#     645
#     646
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GoogleNews-vectors-negative300.bin'

# %%
model.most_similar('frog')
# Out:
# [('eyed', 0.8300723433494568),
#  ('shark', 0.8163352012634277),
#  ('rabbit', 0.8101553916931152),
#  ('pink', 0.8050097227096558),
#  ('crab', 0.8034614324569702),
#  ('scarlet', 0.7912976145744324),
#  ('hairy', 0.7898751497268677),
#  ('winged', 0.7856602668762207),
#  ('stuffed', 0.7845838665962219),
#  ('swan', 0.7798329591751099)]

# %%
s=0
for w in model.wv.vocab:
    s = s+model[w]
mean = s/len(model.wv.vocab)
mean

# %%
def getFV(document):
    
    words=document.split()
    s=np.zeros(200)
    k=0
    for w in words:
        if w in model1.wv.vocab:
            s=s+model1[w]
            k=k+1
    
    return s/k

# %%
getFV("english mother father")
# Out:
# array([-0.1920967 ,  0.72551737,  1.3305739 ,  1.1641924 ,  1.64354753,
#         0.79011761,  0.13885144,  0.90280755, -0.17105255, -0.52310707,
#        -0.86647597,  0.60541626,  1.27097277,  0.72853416, -1.08038698,
#         0.71172499, -0.52265161, -1.82731958,  0.21499215, -0.4297265 ,
#        -1.00684305,  0.19206845,  2.13171609, -0.1866451 , -0.21654577,
#         0.88360703, -0.2212673 , -0.60284929,  0.23822799,  0.72744509,
#         0.10942886,  0.20884407, -1.48303473, -0.29290565,  0.32880607,
#         0.53292724,  0.66007203,  1.32958521, -0.8904136 , -0.42961011,
#         0.04918588,  0.80693745,  0.48354395,  1.37055242,  0.31317511,
#        -0.15162014, -0.01721211, -0.10252297, -0.35961006,  0.2806916 ,
#         1.57799244,  1.93115596, -1.03218201,  0.26650229, -0.74519164,
#        -1.61138872, -0.0553435 ,  0.77471318, -0.27091368,  0.53724706,
#        -0.01296459, -2.7394017 , -0.61044884,  0.05606133, -1.12370396,
#         1.40095318, -0.86684881,  1.02111252,  0.52151245,  0.21628985,
#         0.00444469, -0.40661935,  1.14540756,  0.02473526, -0.63054302,
#         0.61390432,  1.77792879, -0.5666871 , -1.19466267,  0.49829558,
#        -0.16635119, -0.60205735,  0.2916874 ,  0.2787775 ,  0.20043538,
#         0.59530629, -0.2620009 ,  0.93078343,  0.60709381, -1.48770396,
#         0.58424595, -0.481543  ,  1.15332268, -1.92679997, -2.47403558,
#        -1.34774188, -0.38973323,  0.35462222, -0.74522725, -0.98638588,
#        -0.95617603,  0.87756044,  0.28215866, -0.03178713, -0.18737006,
#        -0.08459775,  0.33734909,  0.0951029 ,  0.35689357, -0.07284571,
#         0.33052541,  0.41873169,  1.03684779,  1.58286643,  0.96720471,
#        -0.1340724 ,  0.70067947, -0.88408744,  0.17795989, -2.15312523,
#         0.12187208,  0.17408564,  0.79931674, -0.39975979, -0.22058462,
#         0.85354841, -0.60502132, -0.61712421,  0.25408755, -1.5282224 ,
#         0.26135637, -0.39494197, -0.54670517,  0.55452473, -0.52473765,
#        -0.60660759,  0.9113211 ,  0.1326158 , -0.16654779, -0.46330984,
#        -1.08115228,  0.25834244,  0.63440588, -0.41065524,  0.76786158,
#        -1.57953785, -0.9037074 ,  1.04321311, -0.04828545, -1.04703037,
#        -0.46081545,  0.33545613,  0.72953358, -0.10163758, -0.64339395,
#        -0.57829812, -0.44652031, -0.82112972, -0.71925348, -0.40046227,
#         1.05408229,  0.02814826, -1.93733188,  0.85126169,  0.12227679,
#        -0.12562862, -0.28816614,  0.47425258, -0.74269096, -0.2517605 ,
#        -0.41206669,  0.52634277, -0.39829587, -0.61282291, -0.49121389,
#         0.46511351, -2.40806544, -0.42218721, -0.08347855, -1.15368494,
#         0.50532489, -0.33103872, -0.59728952, -0.78544379,  0.93068641,
#        -0.26845726,  1.24606347,  0.01594961,  1.67191315, -0.31389436,
#         1.22790805, -1.031561  ,  0.97767125,  0.80397781, -0.43464912,
#         0.64738979,  0.42345603,  0.088388  , -0.28685055,  1.30906612])

# %%
sentences2 = word2vec.Text8Corpus(ççç)

# %%
model.build_vocab(sentences2,update=True)

# %%
model.train(sentences2,total_examples=model.corpus_count, epochs=model.iter)
# Out:
# 1901

# %%
model["mundial"]
# Out:
# array([ 0.0460014 ,  0.08693243,  0.0198921 , -0.0639549 ,  0.02383695,
#         0.01312263, -0.06710427, -0.09650418, -0.00638841, -0.03945454,
#         0.03734591,  0.0221463 , -0.05016332,  0.04735284,  0.01347241,
#        -0.03461092,  0.07906207,  0.01796186,  0.05596225,  0.01498506,
#         0.01338899,  0.00857872, -0.01853392,  0.03992237, -0.01842699,
#        -0.05239733,  0.11670461, -0.02744275,  0.08609854,  0.00498559,
#         0.04633285,  0.03566618, -0.00902775,  0.04799515, -0.01413842,
#        -0.03624701, -0.01162697, -0.01055149,  0.05933678,  0.02816383,
#         0.04121719, -0.02386934, -0.07182215, -0.02831256, -0.03332881,
#        -0.01028546, -0.08724254, -0.00781462, -0.00159442, -0.02844645,
#        -0.02853785, -0.050718  , -0.03012423,  0.01588015,  0.03696628,
#         0.04056194,  0.10336589,  0.01096868, -0.07848796,  0.03568391,
#         0.0381955 , -0.03441605, -0.00330844, -0.00865895, -0.00877644,
#         0.05837389, -0.03808545,  0.08126257, -0.00759991, -0.05988626,
#        -0.06969272,  0.03741283, -0.04907243,  0.04257346,  0.02908872,
#         0.01715397,  0.06032326,  0.00327672, -0.07971831, -0.02875996,
#        -0.11212574,  0.048157  ,  0.0159533 ,  0.00446308,  0.04607774,
#        -0.00464089,  0.06259811, -0.00775892,  0.03744533, -0.0350675 ,
#         0.03773503, -0.00222867,  0.0229241 ,  0.02057135,  0.03374975,
#         0.03076628, -0.07261448,  0.02159827, -0.04628809, -0.02771882,
#         0.07558895, -0.02869377,  0.04827448, -0.07218349,  0.00800577,
#         0.09327535, -0.02491081,  0.00248989, -0.01359639, -0.05734383,
#        -0.08686012, -0.09930981,  0.07096246, -0.00312315, -0.07370362,
#         0.07305588, -0.03726192,  0.13771605,  0.02912484,  0.02896119,
#         0.09221828, -0.04970089,  0.0804294 ,  0.05358839,  0.0689536 ,
#         0.00278021,  0.01055886, -0.04572303, -0.07883411,  0.01214812,
#         0.0197032 ,  0.00831418,  0.01148313,  0.01787452, -0.0594387 ,
#         0.03587911, -0.01416574, -0.03167793, -0.03926742,  0.04068792,
#        -0.0384075 , -0.08354207,  0.01250587,  0.06081421,  0.02678413,
#        -0.01935252, -0.01678331, -0.09709922,  0.06211038,  0.02088349,
#        -0.03282236, -0.05838914, -0.02370124,  0.0972272 , -0.0623206 ,
#        -0.00398078, -0.01257988,  0.01959812, -0.06357182,  0.0019235 ,
#         0.00773469, -0.01869055, -0.02691071, -0.05633631,  0.02618524,
#        -0.01149047, -0.05793969,  0.05017669,  0.03867942, -0.03279278,
#        -0.07247429,  0.08912801, -0.00658301,  0.02570284,  0.01514948,
#         0.00326262, -0.05828374,  0.0573624 ,  0.06761412, -0.04196851,
#        -0.01350374, -0.03081739, -0.01904252, -0.05658246,  0.01009917,
#         0.05430309,  0.08892421, -0.09965658,  0.0385679 , -0.01749108,
#        -0.07325672,  0.07399576, -0.06136361,  0.05842467,  0.00243049,
#         0.03748806, -0.00351289,  0.01619194,  0.06229504, -0.01594338],
#       dtype=float32)

# %%
model.most_similar(["Claudio"])
# Out:
# [('Pizarro', 0.9904865026473999),
#  ('volvería', 0.982028603553772),
#  ('2021.', 0.9804888963699341),
#  ('cual', 0.9800978302955627),
#  ('Milan', 0.9779759645462036),
#  ('Gianluigi', 0.9769549369812012),
#  ('años,', 0.9758488535881042),
#  ('razón', 0.975774884223938),
#  ('Donnarumma,', 0.975178599357605),
#  ('AC', 0.9751764535903931)]

# %%
# %%time
model.build_vocab(newwiki, update=True)
model.train(newwiki)
model.save('newmodel')
# model = Word2Vec.load('newmodel')
